# %%
import pandas as pd
import json

pd.options.display.max_columns = 100
pd.reset_option("display.max_colwidth")

# %%
with open('respuesta-fravega.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# %%
# 2️⃣ Extraer los productos dentro del JSON
productos = data["data"]["items"]["results"]

# %%
df = pd.DataFrame(productos)
cols = ['id', 'title', 'katalogCategoryId', 'brand', 'skus','slug']
df = df[cols]
df.head()
# Out:
#                          id  \
# 0  68ad8b1dac9baed38210bbf4
# 1  68c9a32f10aa48b1124182b2
# 2  68c9a34a4057014b7fc264ef
# 3  68c9a37e52c064a49f4b536a
# 4  67f97e4108044aa2211fb90a
#
#                                                title  \
# 0  Asus Rog Flow X13 Amd Ryzen 9 16gb ssd1tb gtx ...
# 1  Asus Vivobook Rosa Core 5 16GB RAM 1TB SSD 14 ...
# 2  Asus Vivobook Rosa Core 5 16GB RAM 512GB SSD 1...
# 3  Asus Vivobook Rosa Core 5 2TB SSD 40GB RAM 14 ...
# 4  Notebook ASUS Vivobook Go 15 15,6” Intel Core ...
#
#           katalogCategoryId  \
# 0  5a301c031400008a0049181b
# 1  5a301c031400008a0049181b
# 2  5a301c031400008a0049181b
# 3  5a301c031400008a0049181b
# 4  5a301c031400008a0049181b
#
#                                                brand  \
# 0  {'id': '5a301bdc140000630049072b', 'name': 'As...
# 1  {'id': '5a301bdc140000630049072b', 'name': 'As...
# 2  {'id': '5a301bdc140000630049072b', 'name': 'As...
# 3  {'id': '5a301bdc140000630049072b', 'name': 'As...
# 4  {'id': '5a301bdc140000630049072b', 'name': 'As...
#
#                                                 skus  \
# 0  {'results': [{'code': '22591597', 'categorizat...
# 1  {'results': [{'code': '990249853', 'categoriza...
# 2  {'results': [{'code': '990249850', 'categoriza...
# 3  {'results': [{'code': '990249854', 'categoriza...
# 4  {'results': [{'code': '364693', 'categorizatio...
#
#                                                 slug
# 0  asus-rog-flow-x13-amd-ryzen-9-16gb-ssd1tb-gtx-...
# 1  asus-vivobook-rosa-core-5-16gb-ram-1tb-ssd-14-...
# 2  asus-vivobook-rosa-core-5-16gb-ram-512gb-ssd-1...
# 3  asus-vivobook-rosa-core-5-2tb-ssd-40gb-ram-14-...
# 4  notebook-asus-vivobook-go-15-15-6”-intel-core-...

# %%
df = pd.json_normalize(df.to_dict('records'), sep='_')
df = df.drop(columns=['brand___typename','skus___typename'], axis=1)

# %%
# ---------- helpers ----------
def ensure_list(v):
    return v if isinstance(v, list) else []

def first_list(v):
    return v[0] if isinstance(v, list) and v else None

def get_category_names_and_slugs(categ):
    """
    'categ' suele ser una lista de rutas (cada ruta es una lista de dicts con name/slug).
    Tomamos la PRIMERA ruta y devolvemos nombres y slugs.
    """
    if not isinstance(categ, list) or not categ:
        return [], []
    ruta = categ[0]
    if not isinstance(ruta, list):
        return [], []
    names = [x.get("name") for x in ruta if isinstance(x, dict)]
    slugs = [x.get("slug") for x in ruta if isinstance(x, dict)]
    return names, slugs

# ---------- 1) Exploto SKUs: una fila por SKU ----------
tmp = df.copy()
tmp["skus_results"] = tmp["skus_results"].apply(ensure_list)
tmp = tmp.explode("skus_results", ignore_index=True)

# Normalizo el dict del SKU en columnas prefijadas
sku_cols = pd.json_normalize(tmp["skus_results"]).add_prefix("sku_")
tmp = tmp.drop(columns=["skus_results"]).join(sku_cols)

# ---------- 2) Me quedo con el pricing preferido (fravega-ecommerce si existe) ----------
# Exploto pricing a filas
tmp["sku_pricing"] = tmp["sku_pricing"].apply(ensure_list)
tmp = tmp.explode("sku_pricing", ignore_index=True)

pricing_cols = pd.json_normalize(tmp["sku_pricing"]).add_prefix("pricing_")
tmp = tmp.drop(columns=["sku_pricing"]).join(pricing_cols)

# Para cada sku_code, quedarme con 'fravega-ecommerce' si existe, sino la primera disponible
# Ordeno para que fravega-ecommerce quede primero
tmp["_pref_order"] = (tmp["pricing_channel"] != "fravega-ecommerce").astype(int)
tmp = tmp.sort_values(["sku_code", "_pref_order"]).drop_duplicates(subset=["sku_code"], keep="first").drop(columns=["_pref_order"])

# ---------- 3) Categorías desde sku_categorization ----------
# sku_categorization suele ser list[list[dict{name, slug}]]
names_slugs = tmp["sku_categorization"].apply(get_category_names_and_slugs)
tmp["category_names"] = names_slugs.apply(lambda x: x[0])
tmp["category_slugs"] = names_slugs.apply(lambda x: x[1])

tmp["category_path"] = tmp["category_names"].apply(lambda ns: " > ".join(ns) if ns else None)
tmp["category_lvl_1"] = tmp["category_names"].apply(lambda ns: ns[0] if isinstance(ns, list) and len(ns) > 0 else None)
tmp["category_lvl_2"] = tmp["category_names"].apply(lambda ns: ns[1] if isinstance(ns, list) and len(ns) > 1 else None)

# ---------- 4) Selección final: ids, categorías, list/offer price ----------
salida = tmp[[
    "id",                 # id del producto
    "sku_code",           # id del SKU
    "category_lvl_1",
    "category_lvl_2",
    "category_path",
    "pricing_listPrice",  # precio de lista
    "pricing_salePrice"   # precio de oferta
]].rename(columns={
    "id": "product_id",
    "sku_code": "sku_id",
    "pricing_listPrice": "list_price",
    "pricing_salePrice": "sale_price"
})

# %%
def ensure_list(v):
    return v if isinstance(v, list) else []

def first_list(v):
    return v[0] if isinstance(v, list) and v else None

def get_category_names(categ):
    """
    'categ' suele ser una lista de rutas (cada ruta es una lista de dicts con name/slug).
    Retorna una lista con todos los nombres de categorías.
    """
    if not isinstance(categ, list) or not categ:
        return []
    ruta = categ[0]
    if not isinstance(ruta, list):
        return []
    return [x.get("name") for x in ruta if isinstance(x, dict)]

# ---------- 1) Exploto SKUs: una fila por SKU ----------
tmp = df.copy()
tmp["skus_results"] = tmp["skus_results"].apply(ensure_list)
tmp = tmp.explode("skus_results", ignore_index=True)

# Normalizo el dict del SKU en columnas
sku_cols = pd.json_normalize(tmp["skus_results"]).add_prefix("sku_")
tmp = tmp.drop(columns=["skus_results"]).join(sku_cols)

# ---------- 2) Exploto pricing ----------
tmp["sku_pricing"] = tmp["sku_pricing"].apply(ensure_list)
tmp = tmp.explode("sku_pricing", ignore_index=True)
pricing_cols = pd.json_normalize(tmp["sku_pricing"]).add_prefix("pricing_")
tmp = tmp.drop(columns=["sku_pricing"]).join(pricing_cols)

# ---------- 3) Priorizar canal 'fravega-ecommerce' ----------
tmp["_pref_order"] = (tmp["pricing_channel"] != "fravega-ecommerce").astype(int)
tmp = tmp.sort_values(["sku_code", "_pref_order"]).drop_duplicates(subset=["sku_code"], keep="first").drop(columns=["_pref_order"])

# ---------- 4) Obtener categorías como lista ----------
tmp["categories"] = tmp["sku_categorization"].apply(get_category_names)

# ---------- 5) Selección final ----------
df_skus = tmp[[
    "id",                 # ID del producto
    "sku_code",           # Código del SKU
    "categories",         # Lista de categorías
    "pricing_listPrice",  # Precio de lista
    "pricing_salePrice"   # Precio de oferta
]].rename(columns={
    "sku_code": "sku_id",
    "pricing_listPrice": "list_price",
    "pricing_salePrice": "sale_price"
})

# %%
df = df.merge(df_skus, on='id').drop('skus_results', axis=1)
# Out:
#                           id  \
# 0   68ad8b1dac9baed38210bbf4
# 1   68c9a32f10aa48b1124182b2
# 2   68c9a34a4057014b7fc264ef
# 3   68c9a37e52c064a49f4b536a
# 4   67f97e4108044aa2211fb90a
# 5   67f97e42bf733aac4d3cc7cb
# 6   67f97e42c7979ac7dd271606
# 7   685ac886050cd74564401161
# 8   67f97e4176c4fb1f831bf6fc
# 9   685ac8869fe01779e6fa50a0
# 10  685ac8919fe01779e6fa50a1
# 11  66d21f173a000005525e8fb1
# 12  685ac88242e29faa03e104c4
# 13  66e7193e270000956604dd23
# 14  678903293e0000be26ba6325
# 15  68c46846a9493c9d1bd31ef4
# 16  67c873d32b00009d1da37bd8
# 17  67e5b26c4282b9599fb2cbdc
# 18  67f97e4208044aa2211fb90b
# 19  68f9461689e082b5b8d2164d
# 20  6791285f4600008ac298b859
# 21  685ac8818ebe5cfa53a0c175
# 22  685ac882edd7b449ed2950de
# 23  64c3e562340000d9a7e0eb21
# 24  6706bc232a0000c21c2054a1
# 25  670fd0bf400000e29de0353e
# 26  678903293e0000d126ba6326
# 27  681a60e16577474ee7c99b15
# 28  681a60e94e219c18d91e438d
# 29  684895c72789596d952f8c38
# 30  689ba197afad7a8ed41d9e8b
# 31  689ca1e491eff1b9e6d56030
# 32  689ca534f30d4518db4ff85a
# 33  68b9c663df3a5d6fa0d0797d
# 34  68bf609f259741148fb734ae
# 35  68c110a8a51bb2968750a0d2
# 36  68c11110d1bb29c6c160edd0
# 37  68e52718cbf759b506654229
# 38  6138918d100000370000f3dc
# 39  63cfe6f0370000d819ef0c26
# 40  64e900203400004f3859c89d
# 41  66f56cb1320000afe7301d24
# 42  66fed902250000182ca2a952
# 0                    [Notebooks, Informática]  8999999.00  5979000.00
# 1                    [Notebooks, Informática]  2207414.00  1709466.00
# 2                    [Notebooks, Informática]  1857524.00  1356366.00
# 3                    [Notebooks, Informática]  2642324.00  2148366.00
# 4                    [Notebooks, Informática]  1199999.00   699999.00
# 5                    [Notebooks, Informática]  1299999.00  1099999.00
# 6                    [Notebooks, Informática]  1849999.00  1299999.00
# 7                    [Notebooks, Informática]  1799999.00  1499999.00
# 8                    [Notebooks, Informática]  3299999.00  2799999.00
# 9                    [Notebooks, Informática]  2199999.00  1949999.00
# 10                   [Notebooks, Informática]  2199999.00  1899999.00
# 11                   [Notebooks, Informática]  4799999.00  3899999.00
# 12                   [Notebooks, Informática]  2999999.00  2549999.00
# 13                   [Notebooks, Informática]  4199999.00  3999999.00
# 14                   [Notebooks, Informática]   799999.00   679999.00
# 15                   [Notebooks, Informática]  1299499.00   679999.00
# 16                   [Notebooks, Informática]  2699999.00  2299999.00
# 17                   [Notebooks, Informática]  1003253.00   924427.00
# 18                   [Notebooks, Informática]  2799999.00  2399999.00
# 19                   [Notebooks, Informática]  1201999.00   829999.00
# 20                   [Notebooks, Informática]  1759999.00   599999.00
# 21                   [Notebooks, Informática]  2899999.00  2449999.00
# 22                   [Notebooks, Informática]  5499999.00  4999999.00
# 23          [Mothers, Gaming PC, Informática]   148419.00   136758.00
# 24          [Mothers, Gaming PC, Informática]   306899.00   273140.11
# 25                   [Notebooks, Informática]   860399.00   645299.00
# 26                   [Notebooks, Informática]  1299999.00   999999.00
# 27                   [Monitores, Informática]   556265.00   417199.00
# 28                   [Monitores, Informática]   473732.00   355299.00
# 29                   [Notebooks, Informática]  1790000.00  1499000.00
# 30                   [Notebooks, Informática]   736500.00   736500.00
# 31                   [Notebooks, Informática]   907199.00   719999.00
# 32                   [Notebooks, Informática]  1370880.00  1142400.00
# 33                   [Notebooks, Informática]  1795104.42  1055947.00
# 34                   [Monitores, Informática]   261399.00   185593.00
# 35                   [Monitores, Informática]   718699.00   510276.00
# 36          [Mothers, Gaming PC, Informática]   202399.00   151799.00
# 37                   [Notebooks, Informática]  1376499.00   991079.00
# 38          [Mothers, Gaming PC, Informática]    98819.00    89836.00
# 39                   [Notebooks, Informática]   917699.00   734159.00
# 40                   [Notebooks, Informática]  1649999.00  1279999.00
# 41        [Gabinetes, Gaming PC, Informática]   255599.00   255599.00
# 42  [Placas de video, Gaming PC, Informática]   642265.00   481699.00
# 43          [Mothers, Gaming PC, Informática]   147499.00   132749.00
# 44          [Mothers, Gaming PC, Informática]   725299.00   603748.99
# 45          [Mothers, Gaming PC, Informática]   251599.00   153475.39
# 46          [Mothers, Gaming PC, Informática]   413699.00   413699.00
# 47          [Mothers, Gaming PC, Informática]  1201999.00   853419.29
# 48                   [Notebooks, Informática]  3326399.00  2395007.00
# 49                   [Notebooks, Informática]  3663000.00  3341904.76
