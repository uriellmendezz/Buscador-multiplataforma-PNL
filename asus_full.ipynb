# %%
import json
import re
import pandas as pd
from pathlib import Path

# -------------------------------
# Helpers
# -------------------------------

def strip_html(s):
    if not s:
        return ""
    return re.sub(r"<[^>]*>", " ", s).strip()

def parse_price(s):
    if not s:
        return None
    s = re.sub(r"[^\d,.\-]", "", s)
    try:
        return float(s.replace(",", ""))
    except ValueError:
        return None

def first_image_url(p: dict):
    if p.get("ProductImage"):
        return p["ProductImage"]
    images = p.get("ImageList") or []
    if images and isinstance(images, list):
        urls = (images[0] or {}).get("ImageURL") or []
        if urls and isinstance(urls, list):
            return urls[0]
    return None

def cargar_json(path: Path):
    try:
        with path.open("r", encoding="utf-8") as f:
            return json.load(f)
    except FileNotFoundError:
        print(f"⚠️ Archivo no encontrado: {path}")
        return None
    except Exception as e:
        print(f"❌ Error leyendo {path}: {e}")
        return None

def records_desde_payload_asus(payload):
    if payload is None:
        return []
    if isinstance(payload, dict):
        return [payload]
    if isinstance(payload, list):
        return [p for p in payload if isinstance(p, dict)]
    return []

def inferir_categoria_desde_filename(path: Path) -> str:
    """
    'ASUS-notebooks.json' -> 'notebooks'
    'ASUS-tarjetas-graficas.json' -> 'tarjetas graficas'
    """
    stem = path.stem  # e.g., 'ASUS-notebooks'
    base = stem.replace("ASUS-", "", 1)
    return base.replace("-", " ").strip()

def transform_asus(p: dict, tienda: str, categoria_principal: str | None = None):
    nombre = strip_html(p.get("Name")) or p.get("SalesModelName") or p.get("CategoryName")

    precio = (
        parse_price(p.get("Price")) or
        parse_price(p.get("RegularPrice")) or
        parse_price(p.get("SortPrice"))
    )

    # ASUS payload no trae moneda/símbolo en estos endpoints
    moneda = None
    simbolo = None

    try:
        estrellas = float(p.get("ReviewStar")) if p.get("ReviewStar") is not None else None
    except (TypeError, ValueError):
        estrellas = None
    reviews = p.get("ReviewCount")

    descripcion = strip_html(p.get("ModelSpec")) or strip_html(p.get("SubTagline")) or ""

    especificaciones = {}  # si luego encontrás un bloque de specs, lo mapeamos aquí

    lvl1, lvl2, lvl3 = p.get("Level1Path"), p.get("Level2Path"), p.get("Level3Path")
    categoria_legible = p.get("CategoryName") or lvl3 or lvl2 or lvl1
    categoria_path = [x for x in [lvl1, lvl2, lvl3] if x]

    imagen = first_image_url(p)
    url = p.get("ProductURL") or p.get("ProductCardURL")
    sku = p.get("PartNo") or p.get("ProductID")
    pid = p.get("ProductID") or p.get("RealProductID")

    return {
        "nombre": nombre,
        "tienda": tienda,
        "categoria_principal": categoria_principal or lvl1 or "ASUS",
        "precio": precio,
        "moneda": moneda,
        "simbolo": simbolo,
        "estrellas": estrellas,
        "reviews": reviews,
        "descripcion": descripcion,
        "especificaciones": especificaciones,
        "categoria": categoria_legible,
        "categoria_path": categoria_path,
        "url": url,
        "imagen": imagen,
        "sku": sku,
        "id": pid,
    }

# -------------------------------
# Proceso para tu carpeta 'datos/asus'
# -------------------------------

def procesar_asus_folder(
    carpeta="datos/asus",
    patron="ASUS-*.json",
    tienda="ASUS",
    guardar_csv="asus_unificado.csv",
    guardar_parquet=None
):
    base = Path(carpeta)
    archivos = sorted(base.glob(patron))
    if not archivos:
        raise FileNotFoundError(f"No se encontraron archivos {patron} en {carpeta}")

    filas = []
    for path in archivos:
        payload = cargar_json(path)
        productos = records_desde_payload_asus(payload)
        if not productos:
            print(f"ℹ️ Sin productos en {path.name}")
            continue

        cat_principal = inferir_categoria_desde_filename(path)  # <- usa el nombre del archivo
        for p in productos:
            filas.append(transform_asus(p, tienda=tienda, categoria_principal=cat_principal))

    df = pd.DataFrame(filas)

    if guardar_csv:
        Path(guardar_csv).parent.mkdir(parents=True, exist_ok=True)
        df.to_csv(guardar_csv, index=False, encoding="utf-8")
        print(f"💾 CSV guardado: {guardar_csv} ({len(df)} filas)")

    if guardar_parquet:
        Path(guardar_parquet).parent.mkdir(parents=True, exist_ok=True)
        df.to_parquet(guardar_parquet, index=False)
        print(f"💾 Parquet guardado: {guardar_parquet} ({len(df)} filas)")

    return df

# %%
df_asus = procesar_asus_folder(
    carpeta="datos/asus",
    patron="ASUS-*.json",
    tienda="ASUS",
    guardar_csv="datos/asus/productos.csv",
    guardar_parquet=None
)
# Out:
# 💾 CSV guardado: datos/asus/productos.csv (479 filas)

# %%
df_asus
# Out:
#                                        nombre tienda categoria_principal  \
# 0                         ROG Delta S Animate   ASUS   auriculares audio
# 1                     ROG Delta White Edition   ASUS   auriculares audio
# 2                        ROG Delta S Wireless   ASUS   auriculares audio
# 3           ROG Cetra II Core Moonlight White   ASUS   auriculares audio
# 4                            ROG Delta S Core   ASUS   auriculares audio
# ..                                        ...    ...                 ...
# 474  ROG Strix Flare II Animate Teclado Gamer   ASUS            teclados
# 475          Teclado Gamer ROG Strix Scope II   ASUS            teclados
# 476                      TUF Gaming K3 Gen II   ASUS            teclados
# 477                             TUF Gaming K3   ASUS            teclados
# 478                             TUF Gaming K1   ASUS            teclados
#
#     precio moneda simbolo  estrellas  reviews  \
# 0     None   None    None        0.0        0
# 1     None   None    None        0.0        0
# 2     None   None    None        0.0        0
# 3     None   None    None        0.0        0
# 4     None   None    None        0.0        0
# ..     ...    ...     ...        ...      ...
# 474   None   None    None        0.0        0
# 475   None   None    None        0.0        0
# 476   None   None    None        4.5      100
# 477   None   None    None        4.5      100
# 478   None   None    None        4.5      100
#
#                                            descripcion especificaciones  \
# 0    Auriculares gaming ligeros USB-C ®  con pantal...               {}
# 1    Auriculares RGB para juegos con Hi-Res ESS Qua...               {}
# 2    Auriculares inalámbricos ligeros para juegos c...               {}
# 3    Auriculares in-ear para gaming ROG Cetra II Co...               {}
# 4    Auriculares ligeros para juegos de 3,5 mm con ...               {}
# ..                                                 ...              ...
# 474  Teclado mecánico para juegos ROG Strix Flare I...               {}
# 475  Teclado gamer ROG Strix Scope II con switches ...               {}
# 476  El teclado ASUS TUF Gaming K3 Gen II incorpora...               {}
# 477  Teclado mecánico ASUS TUF Gaming K3 RGB con te...               {}
# 478  Teclado ASUS TUF Gaming K1 RGB con perilla de ...               {}
#
#                              categoria  \
# 0                  ROG Delta S Animate
# 1              ROG Delta White Edition
# 2                 ROG Delta S Wireless
# 3    ROG Cetra II Core Moonlight White
# 4                     ROG Delta S Core
# ..                                 ...
# 474         ROG Strix Flare II Animate
# 475                 ROG Strix Scope II
# 476                         Alámbricos
# 477                         Alámbricos
# 478                         Alámbricos
#
#                                       categoria_path  \
# 0         [Headsets & Audio, Headsets, USB Headsets]
# 1         [Headsets & Audio, Headsets, USB Headsets]
# 2    [Headsets & Audio, Headsets, Wireless Headsets]
# 3               [Headsets & Audio, In-ear headphone]
# 4       [Headsets & Audio, Headsets, 3.5mm Headsets]
# ..                                               ...
# 474                 [Keyboards, Keyboards, Aura RGB]
# 475                 [Keyboards, Keyboards, Aura RGB]
# 476             [Accessories, Keyboards, TUF-Gaming]
# 477             [Accessories, Keyboards, TUF-Gaming]
# 478             [Accessories, Keyboards, TUF-Gaming]
#
#                                                    url  \
# 0    https://rog.asus.com/ar/headsets-audio/headset...
# 1    https://rog.asus.com/ar/headsets-audio/headset...
# 2    https://rog.asus.com/ar/headsets-audio/headset...
# 3    https://rog.asus.com/ar/headsets-audio/in-ear-...
# 4    https://rog.asus.com/ar/headsets-audio/headset...
# ..                                                 ...
# 474  https://rog.asus.com/ar/keyboards/keyboards/au...
# 475  https://rog.asus.com/ar/keyboards/keyboards/au...
# 476  https://www.asus.com/ar/accessories/keyboards/...
# 477  https://www.asus.com/ar/accessories/keyboards/...
# 478  https://www.asus.com/ar/accessories/keyboards/...
#
#                                                 imagen              sku  \
# 0    https://dlcdnwebimgs.asus.com/gain/459EC147-E7...  90YH037M-B2UA00
# 1    https://dlcdnwebimgs.asus.com/gain/5A3E1722-D3...  90YH02HW-B2UA00
# 2    https://dlcdnwebimgs.asus.com/gain/F223AA9E-DC...  90YH03IW-B3UA00
# 3    https://dlcdnwebimgs.asus.com/gain/A822B517-F1...  90YH0360-B2UA00
# 4    https://dlcdnwebimgs.asus.com/gain/6AA18038-50...  90YH03JC-B1UA00
# ..                                                 ...              ...
# 474  https://dlcdnwebimgs.asus.com/gain/7001B47D-BD...  90MP02E6-BKUA01
# 475  https://dlcdnwebimgs.asus.com/gain/B742E991-0F...  90MP036A-BKAA01
# 476  https://dlcdnwebimgs.asus.com/gain/93739532-e9...            26434
# 477  https://dlcdnwebimgs.asus.com/gain/17b38f2d-d2...            14852
# 478  https://dlcdnwebimgs.asus.com/gain/8f37ce63-3f...            14667
#
#                     id
# 0    R_90YH037M-B2UA00
# 1    R_90YH02HW-B2UA00
# 2    R_90YH03IW-B3UA00
# 3    R_90YH0360-B2UA00
# 4    R_90YH03JC-B1UA00
# ..                 ...
# 474  R_90MP02E6-BKUA01
# 475  R_90MP036A-BKAA01
# 476              26434
# 477              14852
# 478              14667
#
# [479 rows x 16 columns]

# %%
df_lenovo = pd.read_csv('datos/lenovo/productos.csv')
# Out:
#                                         nombre  tienda      precio moneda  \
# 0           IdeaCentre 3 AIO Gen 6 (23.8" AMD)  Lenovo  1240000.01    ARS
# 1         IdeaCentre i AIO Gen 9 (23.8" Intel)  Lenovo  1360000.00    ARS
# 2             IdeaCentre AIO Gen 9 (23.8" AMD)  Lenovo  1429000.01    ARS
# 3           IdeaCentre i AIO Gen 9 (27" Intel)  Lenovo  1450000.00    ARS
# 4  ThinkCentre Neo 50a AIO Gen 5 (23.8" Intel)  Lenovo  1589999.01    ARS
#
#   simbolo  estrellas  reviews  \
# 0       $        4.6     77.0
# 1       $        4.5    123.0
# 2       $        4.6     40.0
# 3       $        4.6    269.0
# 4       $        4.8     61.0
#
#                                          descripcion  \
# 0  <ul style="list-style-type: disc;"><li><p>Eleg...
# 1  <ul style="list-style-type: disc;"><li><p>Máxi...
# 2  <ul style="list-style-type: disc;"><li><p>Rend...
# 3  <ul style="list-style-type: disc;"><li><p>Rend...
# 4  <ul style="list-style-type: disc;"><li><p><spa...
#
#                                     especificaciones  \
# 0  {'Procesador': 'Procesador AMD Ryzen™ 7 7730U ...
# 1  {'Procesador': 'Procesador Intel® Core™ i5-134...
# 2  {'Procesador': 'Procesador AMD Ryzen™ 5 7535HS...
# 3  {'Procesador': 'Procesador Intel® Core™ i5-134...
# 4  {'Procesador': 'Procesador Intel® Core™ i5-134...
#
#                     categoria  \
# 0  Computadoras de Escritorio
# 1  Computadoras de Escritorio
# 2  Computadoras de Escritorio
# 3  Computadoras de Escritorio
# 4  Computadoras de Escritorio
#
#                                       categoria_path  \
# 0  ['ROOTPMI', 'desktops', 'ideacentre', 'aio-300...
# 1  ['ROOTPMI', 'desktops', 'ideacentre', 'aio-500...
# 2  ['ROOTPMI', 'desktops', 'ideacentre', 'aio-500...
# 3  ['ROOTPMI', 'desktops', 'ideacentre', 'aio-500...
# 4  ['ROOTPMI', 'desktops', 'thinkcentre', 'thinkc...
#
#                                                sku  \
# 0  F0G1010SAR_f31ab1f1b6026-4f65-9ed9-0142293b720b
# 1  F0HN00NHAR_f31ab1f1b6026-4f65-9ed9-0142293b720b
# 2  F0HR008QAR_f31ab1f1b6026-4f65-9ed9-0142293b720b
# 3  F0HM00S6AR_f31ab1f1b6026-4f65-9ed9-0142293b720b
# 4  12SD002DAS_f31ab1f1b6026-4f65-9ed9-0142293b720b
#
#                                                  url  \
# 0  /p/computadoras-de-escritorio/ideacentre/serie...
# 1  /p/computadoras-de-escritorio/ideacentre/serie...
# 2  /p/computadoras-de-escritorio/ideacentre/serie...
# 3  /p/computadoras-de-escritorio/ideacentre/serie...
# 4  /p/computadoras-de-escritorio/thinkcentre/thin...
#
#                                               imagen
# 0  https://p1-ofp.static.pub//medias/23389938226_...
# 1  https://p1-ofp.static.pub/medias/26091470103_I...
# 2  https://p1-ofp.static.pub/medias/26091470103_I...
# 3  https://p1-ofp.static.pub/medias/26091470103_I...
# 4  https://p1-ofp.static.pub//medias/26146349384_...

# %%
df = pd.concat([df_asus, df_lenovo]).sort_values(by=['tienda', 'nombre']).reset_index(drop=True)
# Out:
# C:\Users\uriel\AppData\Local\Temp\ipykernel_13424\517229312.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df_asus, df_lenovo]).sort_values(by=['tienda', 'nombre']).reset_index(drop=True)

# %%
df = df.drop('categoria_principal', axis=1)

# %%
df.to_csv('datos/productos-asus-lenovo.csv', index=False)
